# %% [markdown]
# <a href="https://colab.research.google.com/github/naina-modi123/ML-Cohort/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Implementation of logistic regression

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/insurance_data.csv')

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker='*',color='blue')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[['age']], df['bought_insurance'], train_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 10   18
# 5    56
# 7    60
# 6    55
# 23   45
# 2    47

# %%
Y_predicted = model.predict(X_test)

# %%
Y_predicted
# Out:
# array([0, 1, 1, 1, 1, 1])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.95625364, 0.04374636],
#        [0.05584923, 0.94415077],
#        [0.0307697 , 0.9692303 ],
#        [0.06464322, 0.93535678],
#        [0.24671852, 0.75328148],
#        [0.1935101 , 0.8064899 ]])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,Y_predicted)
# Out:
# array([[1, 1],
#        [0, 4]])

# %%
model.score(X_test,Y_test)
# Out:
# 0.8333333333333334

# %%
'THANK YOU'
# Out:
# 'THANK YOU'
